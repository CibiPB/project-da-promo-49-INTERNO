# %%
import pandas as pd
import numpy as np
import re

# %%
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

rawdata = pd.read_csv('../files/hr_raw_data.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 #pd.set_option('display.max_rows', None)
#       2 pd.set_option('display.max_columns', None)
# ----> 4 rawdata = pd.read_csv('../files/hr_raw_data.csv', index_col=0)
#
# File c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../files/hr_raw_data.csv'

# %%
rawdata.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
# 3               4                        1       1         NaN
# 4               5                        1       1         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# 1               2         5             ManAGeR                 3
# 2               3         5             ManaGER                 4
# 3               3         4   ReseArCH DIrECtOr                 3
# 4               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 0           NaN     16280,83$   42330,17$                   7      Y       No
# 1           NaN           NaN   43331,17$                   0    NaN      NaN
# 2       Married           NaN   41669,33$                   1    NaN       No
# 3       Married     14307,50$   37199,50$                   3      Y      NaN
# 4      Divorced     12783,92$   33238,20$                   2      Y       No
#
#    percentsalaryhike performancerating  relationshipsatisfaction  \
# 0                 13               3,0                         3
# 1                 14               3,0                         1
# 2                 11               3,0                         4
# 3                 19               3,0                         2
# 4                 12               3,0                         4
#
#   standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0               NaN                      5
# 1           NaN                 1              34,0                      5
# 2           NaN                 0              22,0                      3
# 3     Full Time                 2               NaN                      2
# 4           NaN                 1               NaN                      5
#
#   worklifebalance  yearsatcompany yearsincurrentrole  yearssincelastpromotion  \
# 0             3,0              20                NaN                       15
# 1             3,0              33                NaN                       11
# 2             NaN              22                NaN                       11
# 3             NaN              20                NaN                        5
# 4             3,0              19                NaN                        2
#
#    yearswithcurrmanager sameasmonthlyincome  datebirth      salary  \
# 0                    15           16280,83$       1972  195370,00$
# 1                     9                 NaN       1971  199990,00$
# 2                    15                 NaN       1981  192320,00$
# 3                     6           14307,50$       1976  171690,00$
# 4                     8           12783,92$       1977         NaN
#
#                         roledepartament  numberchildren remotework
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %%
rawdata['education'].notnull().sum()
# Out:
# 1678

# %%
rawdata['education'].unique()
# Out:
# array([3, 4, 2, 1, 5], dtype=int64)

# %% [markdown]
# #### DATA NOTES:
#
# - Employeenumber = PRIMARY KEY : THERE ARE DUPLICATES
# -
#
#
# TO CHANGE:
#
# - Distance from home has negative values, replace for 'null'?
# - Nan to Null?
# - Genger from int to tag
#
# - dailyrate , salary, sameasmonthlyincome: remove $ and change type to float(2)
# - Group all salary rates near by
#
# RENAME:
#
# - Rename from: Attrition to: rehired
# - Rename from: Salary to: AnnualSalary
# - Rename from: Education Field
#
# DELETE:
# - employeecount: All values are same / unique = rawdata['employeecount'].unique() and can be done by employee number
#
# DUPLICATES:
# - Employeenumber / dupli = rawdata['employeenumber'].duplicated()

# %%
rawdata.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
# 3               4                        1       1         NaN
# 4               5                        1       1         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# 1               2         5             ManAGeR                 3
# 2               3         5             ManaGER                 4
# 3               3         4   ReseArCH DIrECtOr                 3
# 4               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 0           NaN     16280,83$   42330,17$                   7      Y       No
# 1           NaN           NaN   43331,17$                   0    NaN      NaN
# 2       Married           NaN   41669,33$                   1    NaN       No
# 3       Married     14307,50$   37199,50$                   3      Y      NaN
# 4      Divorced     12783,92$   33238,20$                   2      Y       No
#
#    percentsalaryhike performancerating  relationshipsatisfaction  \
# 0                 13               3,0                         3
# 1                 14               3,0                         1
# 2                 11               3,0                         4
# 3                 19               3,0                         2
# 4                 12               3,0                         4
#
#   standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0               NaN                      5
# 1           NaN                 1              34,0                      5
# 2           NaN                 0              22,0                      3
# 3     Full Time                 2               NaN                      2
# 4           NaN                 1               NaN                      5
#
#   worklifebalance  yearsatcompany yearsincurrentrole  yearssincelastpromotion  \
# 0             3,0              20                NaN                       15
# 1             3,0              33                NaN                       11
# 2             NaN              22                NaN                       11
# 3             NaN              20                NaN                        5
# 4             3,0              19                NaN                        2
#
#    yearswithcurrmanager sameasmonthlyincome  datebirth      salary  \
# 0                    15           16280,83$       1972  195370,00$
# 1                     9                 NaN       1971  199990,00$
# 2                    15                 NaN       1981  192320,00$
# 3                     6           14307,50$       1976  171690,00$
# 4                     8           12783,92$       1977         NaN
#
#                         roledepartament  numberchildren remotework
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %%
rawdata.duplicated().sum()
# Out:
# 64

# %%
pd.set_option('display.max_columns', None) #para mostrar todas las columnas

# %% [markdown]
# Potenciales drops de filas:

# %%
rawdata[rawdata.duplicated()] #buscar para mover la columna de employeenumber
# Out:
#      age attrition businesstravel    dailyrate         department  \
# 1614  35        No            NaN  1032.487286                NaN
# 1615  59        No  travel_rarely   290.035510   Human Resources
# 1616  30        No  travel_rarely  1032.487286                NaN
# 1617  34       Yes  travel_rarely   556.256661                NaN
# 1618  47        No            NaN   290.035510                NaN
# ...   ..       ...            ...          ...                ...
# 1673  43        No            NaN   488.944444                NaN
# 1674  47        No            NaN  1973.984127                NaN
# 1675  29        No  travel_rarely   290.035510                NaN
# 1676  47        No  travel_rarely  1032.487286                NaN
# 1677  32        No            NaN   556.256661                NaN
#
#       distancefromhome  education educationfield  employeecount  \
# 1614                18          5  Life Sciences              1
# 1615                 6          2        Medical              1
# 1616                 5          3            NaN              1
# 1617                24          4            NaN              1
# 1618                 2          4  Life Sciences              1
# ...                ...        ...            ...            ...
# 1673               -26          3        Medical              1
# 1674                26          4            NaN              1
# 1675                15          3            NaN              1
# 1676                 4          3  Life Sciences              1
# 1677                 2          2  Life Sciences              1
#
#       employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 1614             178                        2       0         NaN
# 1615             853                        2       0         NaN
# 1616             112                        2       1  129.060911
# 1617             159                        1       1         NaN
# 1618             969                        4       1         NaN
# ...              ...                      ...     ...         ...
# 1673             824                        2       1         NaN
# 1674            1087                        4       1         NaN
# 1675             528                        3       0         NaN
# 1676              76                        3       1         NaN
# 1677             401                        4       1   69.532083
#
#       jobinvolvement  joblevel                   jobrole  jobsatisfaction  \
# 1614               3         3          sAlES eXeCuTIVe                 1
# 1615               3         1          humAN resoURCEs                 3
# 1616               3         3          SalES ExeCuTIVe                 4
# 1617               2         2          sAles EXecutiVE                 2
# 1618               2         1     SALeS RePreSenTATiVe                 4
# ...              ...       ...                       ...              ...
# 1673               4         1       rESEaRcH SciEnTiST                 3
# 1674               3         5                  mANager                 3
# 1675               3         1       reSearch sCienTiSt                 4
# 1676               2         3   maNufACTURING DIREctOr                 2
# 1677               3         2       resEArch scIENTisT                 3
#
#      maritalstatus monthlyincome monthlyrate  numcompaniesworked over18  \
# 1614       Married      8339,32$   21682,23$                   1      Y
# 1615       Married      2342,59$    6090,75$                   8      Y
# 1616           NaN      8339,32$   21682,23$                   2      Y
# 1617        Single           NaN   11681,39$                   0      Y
# 1618        Single      2342,59$    6090,75$                   1    NaN
# ...            ...           ...         ...                 ...    ...
# 1673        Single      3949,17$   10267,83$                   4    NaN
# 1674       Married     15943,72$   41453,67$                   3      Y
# 1675           NaN           NaN    6090,75$                   1    NaN
# 1676      Divorced      8339,32$   21682,23$                   8    NaN
# 1677        Single           NaN   11681,39$                   4      Y
#
#      overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# 1614      NaN                 22               4,0                         4
# 1615      NaN                 17               3,0                         4
# 1616       No                 12               3,0                         3
# 1617      Yes                 23               4,0                         3
# 1618      Yes                 18               3,0                         1
# ...       ...                ...               ...                       ...
# 1673      NaN                 12               3,0                         4
# 1674       No                 11               3,0                         3
# 1675       No                 19               3,0                         1
# 1676      Yes                 12               NaN                         3
# 1677      Yes                 14               3,0                         4
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 1614           NaN                 1               9,0                      3
# 1615     Part Time                 0               NaN                      2
# 1616     Part Time                 1               NaN                      2
# 1617     Part Time                 0              16,0                      2
# 1618           NaN                 0               3,0                      3
# ...            ...               ...               ...                    ...
# 1673           NaN                 0               NaN                      2
# 1674     Full Time                 1              27,0                      2
# 1675     Part Time                 0               6,0                      1
# 1676     Part Time                 1               NaN                      4
# 1677     Part Time                 0              10,0                      2
#
#      worklifebalance  yearsatcompany yearsincurrentrole  \
# 1614             2,0               9                NaN
# 1615             2,0               2                NaN
# 1616             3,0              10                NaN
# 1617             4,0              15                NaN
# 1618             2,0               3                NaN
# ...              ...             ...                ...
# 1673             3,0               3                NaN
# 1674             3,0               5                NaN
# 1675             3,0               6                NaN
# 1676             3,0              22                NaN
# 1677             3,0               8                NaN
#
#       yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# 1614                        1                     8            8339,32$
# 1615                        2                     2            2342,59$
# 1616                        7                     4            8339,32$
# 1617                       10                    10                 NaN
# 1618                        1                     2            2342,59$
# ...                       ...                   ...                 ...
# 1673                        1                     2            3949,17$
# 1674                        1                     0           15943,72$
# 1675                        1                     5                 NaN
# 1676                       14                    10            8339,32$
# 1677                        0                     7                 NaN
#
#       datebirth      salary                        roledepartament  \
# 1614       1988         NaN                                    NaN
# 1615       1964   28111,13$   humAN resoURCEs  -  Human Resources
# 1616       1993  100071,84$                                    NaN
# 1617       1989   53914,11$                                    NaN
# 1618       1976         NaN                                    NaN
# ...         ...         ...                                    ...
# 1673       1980         NaN                                    NaN
# 1674       1976  191324,62$                                    NaN
# 1675       1994   28111,13$                                    NaN
# 1676       1976  100071,84$                                    NaN
# 1677       1991   53914,11$                                    NaN
#
#       numberchildren remotework
# 1614             NaN       True
# 1615             NaN      False
# 1616             NaN       True
# 1617             NaN          0
# 1618             NaN          1
# ...              ...        ...
# 1673             NaN        Yes
# 1674             NaN      False
# 1675             NaN      False
# 1676             NaN        Yes
# 1677             NaN          0
#
# [64 rows x 41 columns]

# %%
rawdata[rawdata.duplicated(subset='employeenumber', keep=True)].sort_values('employeenumber')
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 60    36        No            NaN   610.174603        NaN                 5
# 1652  36        No            NaN   610.174603        NaN                 5
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# ...   ..       ...            ...          ...        ...               ...
# 1638  48        No  travel_rarely   417.960317        NaN                 2
# 1657  45        No  travel_rarely   495.753968        NaN                 2
# 1568  45        No  travel_rarely   495.753968        NaN                 2
# 1671  31        No            NaN   556.256661        NaN                12
# 1607  31        No            NaN   556.256661        NaN                12
#
#       education educationfield  employeecount  employeenumber  \
# 8             5            NaN              1               9
# 1656          5            NaN              1               9
# 60            2            NaN              1              61
# 1652          2            NaN              1              61
# 1676          3  Life Sciences              1              76
# ...         ...            ...            ...             ...
# 1638          5            NaN              1            1568
# 1657          3          Other              1            1569
# 1568          3          Other              1            1569
# 1671          3        Medical              1            1608
# 1607          3        Medical              1            1608
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 8                           2       1         NaN               3         4
# 1656                        2       1         NaN               3         4
# 60                          4       0         NaN               3         2
# 1652                        4       0         NaN               3         2
# 1676                        3       1         NaN               2         3
# ...                       ...     ...         ...             ...       ...
# 1638                        2       1         NaN               3         2
# 1657                        4       0         NaN               3         2
# 1568                        4       0         NaN               3         2
# 1671                        4       1         NaN               3         2
# 1607                        4       1         NaN               3         2
#
#                           jobrole  jobsatisfaction maritalstatus  \
# 8                        mANAGEr                 1       Married
# 1656                     mANAGEr                 1       Married
# 60         lAboratORy TeChNiCiaN                 2        Single
# 1652       lAboratORy TeChNiCiaN                 2        Single
# 1676      maNufACTURING DIREctOr                 2      Divorced
# ...                           ...              ...           ...
# 1638             sALES EXEcuTIVe                 4       Married
# 1657             sAles executiVe                 2           NaN
# 1568             sAles executiVe                 2           NaN
# 1671   HEaltHCarE REPreSENtAtIve                 4           NaN
# 1607   HEaltHCarE REPreSENtAtIve                 4           NaN
#
#      monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 8        13829,17$   35955,83$                   7    NaN       No
# 1656     13829,17$   35955,83$                   7    NaN       No
# 60        4928,33$   12813,67$                   8      Y       No
# 1652      4928,33$   12813,67$                   8      Y       No
# 1676      8339,32$   21682,23$                   8    NaN      Yes
# ...            ...         ...                 ...    ...      ...
# 1638      3375,83$    8777,17$                   2    NaN       No
# 1657           NaN   10410,83$                   0    NaN       No
# 1568           NaN   10410,83$                   0    NaN       No
# 1671           NaN   11681,39$                   0    NaN      NaN
# 1607           NaN   11681,39$                   0    NaN      NaN
#
#       percentsalaryhike performancerating  relationshipsatisfaction  \
# 8                    16               3,0                         2
# 1656                 16               3,0                         2
# 60                   16               3,0                         4
# 1652                 16               3,0                         4
# 1676                 12               NaN                         3
# ...                 ...               ...                       ...
# 1638                 14               3,0                         1
# 1657                 19               3,0                         2
# 1568                 19               3,0                         2
# 1671                 11               3,0                         3
# 1607                 11               3,0                         3
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 8        Full Time                 1              22,0                      2
# 1656     Full Time                 1              22,0                      2
# 60       Full Time                 0              16,0                      3
# 1652     Full Time                 0              16,0                      3
# 1676     Part Time                 1               NaN                      4
# ...            ...               ...               ...                    ...
# 1638     Part Time                 1              14,0                      2
# 1657     Part Time                 1               NaN                      3
# 1568     Part Time                 1               NaN                      3
# 1671     Part Time                 2              10,0                      2
# 1607     Part Time                 2              10,0                      2
#
#      worklifebalance  yearsatcompany yearsincurrentrole  \
# 8                3,0              18                NaN
# 1656             3,0              18                NaN
# 60               4,0              13                NaN
# 1652             4,0              13                NaN
# 1676             3,0              22                NaN
# ...              ...             ...                ...
# 1638             3,0               9                NaN
# 1657             4,0               8                NaN
# 1568             4,0               8                NaN
# 1671             1,0               9                NaN
# 1607             1,0               9                NaN
#
#       yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# 8                          11                     8           13829,17$
# 1656                       11                     8           13829,17$
# 60                          3                     7            4928,33$
# 1652                        3                     7            4928,33$
# 1676                       14                    10            8339,32$
# ...                       ...                   ...                 ...
# 1638                        6                     7            3375,83$
# 1657                        3                     7                 NaN
# 1568                        3                     7                 NaN
# 1671                        8                     5                 NaN
# 1607                        8                     5                 NaN
#
#       datebirth      salary roledepartament  numberchildren remotework
# 8          1982  165950,00$             NaN             NaN       True
# 1656       1982  165950,00$             NaN             NaN       True
# 60         1987   59140,00$             NaN             NaN          1
# 1652       1987   59140,00$             NaN             NaN          1
# 1676       1976  100071,84$             NaN             NaN        Yes
# ...         ...         ...             ...             ...        ...
# 1638       1975   40510,00$             NaN             NaN       True
# 1657       1978   48050,00$             NaN             NaN      False
# 1568       1978   48050,00$             NaN             NaN      False
# 1671       1992   53914,11$             NaN             NaN       True
# 1607       1992   53914,11$             NaN             NaN       True
#
# [128 rows x 41 columns]

# %%
rawdata = rawdata.drop_duplicates(keep='first')

# %%
rawdata.shape
# Out:
# (1614, 41)

# %%
rawdata.set_index('employeenumber', drop=True, inplace=True)

# %%
rawdata.head(1)
# Out:
#                age attrition businesstravel    dailyrate department  \
# employeenumber
# 1               51        No            NaN  2015.722222        NaN
#
#                 distancefromhome  education educationfield  employeecount  \
# employeenumber
# 1                              6          3            NaN              1
#
#                 environmentsatisfaction  gender  hourlyrate  jobinvolvement  \
# employeenumber
# 1                                     1       0         NaN               3
#
#                 joblevel              jobrole  jobsatisfaction maritalstatus  \
# employeenumber
# 1                      5   resEArch DIREcToR                 3           NaN
#
#                monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# employeenumber
# 1                  16280,83$   42330,17$                   7      Y       No
#
#                 percentsalaryhike performancerating  relationshipsatisfaction  \
# employeenumber
# 1                              13               3,0                         3
#
#                standardhours  stockoptionlevel totalworkingyears  \
# employeenumber
# 1                  Full Time                 0               NaN
#
#                 trainingtimeslastyear worklifebalance  yearsatcompany  \
# employeenumber
# 1                                   5             3,0              20
#
#                yearsincurrentrole  yearssincelastpromotion  \
# employeenumber
# 1                             NaN                       15
#
#                 yearswithcurrmanager sameasmonthlyincome  datebirth  \
# employeenumber
# 1                                 15           16280,83$       1972
#
#                     salary roledepartament  numberchildren remotework
# employeenumber
# 1               195370,00$             NaN             NaN        Yes

# %%
rawdata.drop(['numberchildren', 'employeecount', 'over18'], axis=1, inplace=True)

# %%
rawdata.drop('sameasmonthlyincome', axis=1, inplace=True)

# %%
title_mapping = {
    "employeenumber": "employee_number",
    "gender": "gender",
    "datebirth": "birth_year",
    "age": "age",
    "maritalstatus": "marital_status",
    "jobrole": "job_title",
    "department": "department",
    "attrition": "terminated",
    "standardhours": "standard_hours",
    "monthlyincome": "monthly_income",
    "remotework": "remote",
    "businesstravel": "business_travel",
    "dailyrate": "daily_rate",
    "distancefromhome": "dist_home",
    "education": "education_scale",
    "educationfield": "education",
    "environmentsatisfaction": "env_sat_rate",
    "hourlyrate": "hourly_rate",
    "jobinvolvement": "job_involvement",
    "joblevel": "job_level",
    "jobsatisfaction": "job_sat_rate",
    "monthlyrate": "monthly_rate",
    "numcompaniesworked": "num_comp_worked",
    "overtime": "over_time",
    "percentsalaryhike": "perc_salary_hike",
    "performancerating": "perf_rate",
    "relationshipsatisfaction": "relationship_sat_rate",
    "stockoptionlevel": "stock_opt_level",
    "totalworkingyears": "tot_working_year",
    "trainingtimeslastyear": "traning_times_last_year",
    "worklifebalance": "work_life_balance",
    "yearsatcompany": "year_at_comp",
    "yearsincurrentrole": "year_current_role",
    "yearssincelastpromotion": "year_last_promotion",
    "yearswithcurrmanager": "year_current_mngr",
    "salary": "annual_salary",
    "roledepartament": "role_department"}

# %%
rawdata= rawdata.rename(columns=title_mapping)

# %%
rawdata[["role_1", "department_1"]]=rawdata["role_department"].str.split("-", expand=True).get([0, 1])

# %%
rawdata.head()
# Out:
#                age terminated business_travel   daily_rate  \
# employeenumber
# 1               51         No             NaN  2015.722222
# 2               52         No             NaN  2063.388889
# 3               42         No   travel_rarely  1984.253968
# 4               47         No   travel_rarely  1771.404762
# 5               46         No             NaN  1582.771346
#
#                               department  dist_home  education_scale  \
# employeenumber
# 1                                    NaN          6                3
# 2                                    NaN          1                4
# 3                Research & Development           4                2
# 4                                    NaN          2                4
# 5                                    NaN          3                3
#
#                        education  env_sat_rate  gender  hourly_rate  \
# employeenumber
# 1                            NaN             1       0          NaN
# 2                  Life Sciences             3       0          NaN
# 3               Technical Degree             3       0          NaN
# 4                        Medical             1       1          NaN
# 5               Technical Degree             1       1          NaN
#
#                 job_involvement  job_level            job_title  job_sat_rate  \
# employeenumber
# 1                             3          5   resEArch DIREcToR              3
# 2                             2          5             ManAGeR              3
# 3                             3          5             ManaGER              4
# 4                             3          4   ReseArCH DIrECtOr              3
# 5                             4          4     sAleS EXECUtIve              1
#
#                marital_status monthly_income monthly_rate  num_comp_worked  \
# employeenumber
# 1                         NaN      16280,83$    42330,17$                7
# 2                         NaN            NaN    43331,17$                0
# 3                     Married            NaN    41669,33$                1
# 4                     Married      14307,50$    37199,50$                3
# 5                    Divorced      12783,92$    33238,20$                2
#
#                over_time  perc_salary_hike perf_rate  relationship_sat_rate  \
# employeenumber
# 1                     No                13       3,0                      3
# 2                    NaN                14       3,0                      1
# 3                     No                11       3,0                      4
# 4                    NaN                19       3,0                      2
# 5                     No                12       3,0                      4
#
#                standard_hours  stock_opt_level tot_working_year  \
# employeenumber
# 1                   Full Time                0              NaN
# 2                         NaN                1             34,0
# 3                         NaN                0             22,0
# 4                   Full Time                2              NaN
# 5                         NaN                1              NaN
#
#                 traning_times_last_year work_life_balance  year_at_comp  \
# employeenumber
# 1                                     5               3,0            20
# 2                                     5               3,0            33
# 3                                     3               NaN            22
# 4                                     2               NaN            20
# 5                                     5               3,0            19
#
#                year_current_role  year_last_promotion  year_current_mngr  \
# employeenumber
# 1                            NaN                   15                 15
# 2                            NaN                   11                  9
# 3                            NaN                   11                 15
# 4                            NaN                    5                  6
# 5                            NaN                    2                  8
#
#                 birth_year annual_salary  \
# employeenumber
# 1                     1972    195370,00$
# 2                     1971    199990,00$
# 3                     1981    192320,00$
# 4                     1976    171690,00$
# 5                     1977           NaN
#
#                                      role_department remote      role_1  \
# employeenumber
# 1                                                NaN    Yes         NaN
# 2                                                NaN      1         NaN
# 3                ManaGER  -  Research & Development       1   ManaGER
# 4                                                NaN  False         NaN
# 5                                                NaN      0         NaN
#
#                              department_1
# employeenumber
# 1                                     NaN
# 2                                     NaN
# 3                 Research & Development
# 4                                     NaN
# 5                                     NaN

# %%
rawdata.loc[:15, ["job_title", "role_1", "department", "department_1", "role_department"]]
# Out:
#                                job_title      role_1  \
# employeenumber
# 1                     resEArch DIREcToR          NaN
# 2                               ManAGeR          NaN
# 3                               ManaGER    ManaGER
# 4                     ReseArCH DIrECtOr          NaN
# 5                       sAleS EXECUtIve          NaN
# 6                               MANAger    MANAger
# 7                       Sales ExeCutIVe          NaN
# 8                       Sales eXEcUTiVe          NaN
# 9                               mANAGEr          NaN
# 10                    reSEaRCH DIrectoR          NaN
# 11                    RESeArcH DIrEctoR          NaN
# 12               MANUfACturing DIReCtOr          NaN
# 13                    REseaRCh dirEcToR          NaN
# 14                    reseARCh DIrEctoR          NaN
# 15                    RESeaRCH dirEctor          NaN
#
#                               department               department_1  \
# employeenumber
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                Research & Development     Research & Development
# 4                                    NaN                        NaN
# 5                                    NaN                        NaN
# 6                Research & Development     Research & Development
# 7                                    NaN                        NaN
# 8                                    NaN                        NaN
# 9                                    NaN                        NaN
# 10                                   NaN                        NaN
# 11                                   NaN                        NaN
# 12                                   NaN                        NaN
# 13                                   NaN                        NaN
# 14                                   NaN                        NaN
# 15                                   NaN                        NaN
#
#                                      role_department
# employeenumber
# 1                                                NaN
# 2                                                NaN
# 3                ManaGER  -  Research & Development
# 4                                                NaN
# 5                                                NaN
# 6                MANAger  -  Research & Development
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN

# %%
rawdata.drop(['role_1', 'department_1', 'role_department'], axis=1, inplace=True)

# %%
rawdata.head()
# Out:
#                age terminated business_travel   daily_rate  \
# employeenumber
# 1               51         No             NaN  2015.722222
# 2               52         No             NaN  2063.388889
# 3               42         No   travel_rarely  1984.253968
# 4               47         No   travel_rarely  1771.404762
# 5               46         No             NaN  1582.771346
#
#                               department  dist_home  education_scale  \
# employeenumber
# 1                                    NaN          6                3
# 2                                    NaN          1                4
# 3                Research & Development           4                2
# 4                                    NaN          2                4
# 5                                    NaN          3                3
#
#                        education  env_sat_rate  gender  hourly_rate  \
# employeenumber
# 1                            NaN             1       0          NaN
# 2                  Life Sciences             3       0          NaN
# 3               Technical Degree             3       0          NaN
# 4                        Medical             1       1          NaN
# 5               Technical Degree             1       1          NaN
#
#                 job_involvement  job_level            job_title  job_sat_rate  \
# employeenumber
# 1                             3          5   resEArch DIREcToR              3
# 2                             2          5             ManAGeR              3
# 3                             3          5             ManaGER              4
# 4                             3          4   ReseArCH DIrECtOr              3
# 5                             4          4     sAleS EXECUtIve              1
#
#                marital_status monthly_income monthly_rate  num_comp_worked  \
# employeenumber
# 1                         NaN      16280,83$    42330,17$                7
# 2                         NaN            NaN    43331,17$                0
# 3                     Married            NaN    41669,33$                1
# 4                     Married      14307,50$    37199,50$                3
# 5                    Divorced      12783,92$    33238,20$                2
#
#                over_time  perc_salary_hike perf_rate  relationship_sat_rate  \
# employeenumber
# 1                     No                13       3,0                      3
# 2                    NaN                14       3,0                      1
# 3                     No                11       3,0                      4
# 4                    NaN                19       3,0                      2
# 5                     No                12       3,0                      4
#
#                standard_hours  stock_opt_level tot_working_year  \
# employeenumber
# 1                   Full Time                0              NaN
# 2                         NaN                1             34,0
# 3                         NaN                0             22,0
# 4                   Full Time                2              NaN
# 5                         NaN                1              NaN
#
#                 traning_times_last_year work_life_balance  year_at_comp  \
# employeenumber
# 1                                     5               3,0            20
# 2                                     5               3,0            33
# 3                                     3               NaN            22
# 4                                     2               NaN            20
# 5                                     5               3,0            19
#
#                year_current_role  year_last_promotion  year_current_mngr  \
# employeenumber
# 1                            NaN                   15                 15
# 2                            NaN                   11                  9
# 3                            NaN                   11                 15
# 4                            NaN                    5                  6
# 5                            NaN                    2                  8
#
#                 birth_year annual_salary remote
# employeenumber
# 1                     1972    195370,00$    Yes
# 2                     1971    199990,00$      1
# 3                     1981    192320,00$      1
# 4                     1976    171690,00$  False
# 5                     1977           NaN      0
